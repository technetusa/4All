# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **S Mathuram**
# Watson Data Scientist

# %% [markdown]
# *I am interested in Data Science because I want to be Data Scientist analyzing data visualization skills as well as interepret data to gain various insights and predict future decisions*

# %% [markdown]
# ###The code below will print "Hello World".###

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Horizontal Rule:**
# ***
# Hi Everyone!
# Hope you all are doing good!!!
# ***
#
# <a href="https://cloud.ibm.com/" target="_blank"> IBM Cloud</a>
#
# ![alt text](https://www.fullstackpython.com/img/logos/markdown.png)
